# %% [markdown]
# # SkillPulse — Setup & Data Collection
# Run cells top to bottom. Make sure `.env` and MySQL are set up first (see README notes).

# %% [markdown]
# ## 1. Imports

# %%
import json as pyjson

# %%
import os
import time
import requests
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
from urllib.parse import quote_plus

load_dotenv(dotenv_path="../.env")  # reads variables from .env in the same folder
# Out:
# True

# %% [markdown]
# ## 2. Connect to MySQL
# This reads credentials from `.env` — never hardcode them here.

# %%
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

#engine = create_engine(f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
engine = create_engine(f"mysql+pymysql://{DB_USER}:{quote_plus(DB_PASSWORD)}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
# quick connection test
with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES;"))
    print("Connected. Tables found:", [row[0] for row in result])
# Out:
# Connected. Tables found: ['drift_reports', 'job_postings', 'job_skills', 'model_runs', 'skills']

# %% [markdown]
# ## 3. Adzuna scraper function
# Pulls one page of results at a time.

# %%
ADZUNA_APP_ID = os.getenv("ADZUNA_APP_ID")
ADZUNA_APP_KEY = os.getenv("ADZUNA_APP_KEY")

def fetch_page(page, country="in", keyword="data scientist", results_per_page=50):
    url = f"https://api.adzuna.com/v1/api/jobs/{country}/search/{page}"
    params = {
        "app_id": ADZUNA_APP_ID,
        "app_key": ADZUNA_APP_KEY,
        "results_per_page": results_per_page,
        "what": keyword,
        "content-type": "application/json",
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json().get("results", [])

# %% [markdown]
# ## 4. Test pull — small batch first
# Check salary-field coverage before running the full 5,000–10,000 pull.

# %%
test_results = fetch_page(page=1, keyword="data scientist", results_per_page=50)
df_test = pd.json_normalize(test_results)
print("Rows pulled:", len(df_test))

for col in ["salary_min", "salary_max"]:
    if col not in df_test.columns:
        df_test[col] = pd.NA

print("Salary fields populated:", df_test[["salary_min", "salary_max"]].notna().mean())
df_test.head()
# Out:
# Rows pulled: 50
# Salary fields populated: salary_min    0.06
# salary_max    0.06
# dtype: float64
#                                          description          id  longitude  \
# 0  Data Science Instructor (Jaipur) upGrad is exp...  5806140450  75.946900
# 1  Data Science & AI Instructor upGrad is expandi...  5786785503        NaN
# 2  Job Title: Data Science Instructor – Offline L...  5806136048  79.905350
# 3  Part-Time Data Science & AI Instructor (Chandi...  5786785222  76.760940
# 4  Designation: Assistant Professor - Computer Sc...  5787965226  74.014575
#
#                     __CLASS__  \
# 0  Adzuna::API::Response::Job
# 1  Adzuna::API::Response::Job
# 2  Adzuna::API::Response::Job
# 3  Adzuna::API::Response::Job
# 4  Adzuna::API::Response::Job
#
#                                         redirect_url               created  \
# 0  https://www.adzuna.in/land/ad/5806140450?se=4G...  2026-07-18T18:10:14Z
# 1  https://www.adzuna.in/land/ad/5786785503?se=4G...  2026-07-03T17:37:09Z
# 2  https://www.adzuna.in/land/ad/5806136048?se=4G...  2026-07-18T18:07:28Z
# 3  https://www.adzuna.in/land/ad/5786785222?se=4G...  2026-07-03T17:35:51Z
# 4  https://www.adzuna.in/land/ad/5787965226?se=4G...  2026-07-04T17:07:19Z
#
#                                                title salary_is_predicted  \
# 0                            Data Science Instructor                   0
# 1                            Data Science Instructor                   0
# 2                            Data Science Instructor                   0
# 3                  Part time Data Science Instructor                   0
# 4  Assistant Professor of Computer Science (Data ...                   0
#
#                                                adref  latitude  ...  \
# 0  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTgwNjE0MDQ1MCIsI...  26.74410  ...
# 1  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc4Njc4NTUwMyIsI...       NaN  ...
# 2  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNEdYMk1VT0Q4UkdGN...  23.13080  ...
# 3  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNEdYMk1VT0Q4UkdGN...  30.75395  ...
# 4  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNEdYMk1VT0Q4UkdGN...  15.35420  ...
#
#          category.tag   company.display_name               company.__CLASS__  \
# 0             it-jobs                 upGrad  Adzuna::API::Response::Company
# 1             it-jobs                 upGrad  Adzuna::API::Response::Company
# 2             it-jobs                 upGrad  Adzuna::API::Response::Company
# 3      part-time-jobs                 upGrad  Adzuna::API::Response::Company
# 4  scientific-qa-jobs  Ganpat University Goa  Adzuna::API::Response::Company
#
#                 location.__CLASS__                      location.area  \
# 0  Adzuna::API::Response::Location         [India, Rajasthan, Jaipur]
# 1  Adzuna::API::Response::Location                            [India]
# 2  Adzuna::API::Response::Location  [India, Madhya Pradesh, Jabalpur]
# 3  Adzuna::API::Response::Location                [India, Chandigarh]
# 4  Adzuna::API::Response::Location                       [India, Goa]
#
#       location.display_name contract_time contract_type salary_max salary_min
# 0         Jaipur, Rajasthan           NaN           NaN        NaN        NaN
# 1                     India           NaN           NaN        NaN        NaN
# 2  Jabalpur, Madhya Pradesh           NaN           NaN        NaN        NaN
# 3         Chandigarh, India     part_time           NaN        NaN        NaN
# 4                Goa, India           NaN           NaN        NaN        NaN
#
# [5 rows x 22 columns]

# %%
import json
print(json.dumps(test_results[0], indent=2))
# Out:
# {
#   "category": {
#     "__CLASS__": "Adzuna::API::Response::Category",
#     "label": "IT Jobs",
#     "tag": "it-jobs"
#   },
#   "description": "Data Science Instructor (Jaipur) upGrad is expanding its Offline Learning Centres , and we are looking for a dynamic Data Science Instructor in Jaipur Key Responsibilities As a Instructor, you will play a vital role in ensuring high-quality learning outcomes: Deliver High-Impact Sessions: Conduct engaging, in-person lectures and hands-on training sessions in Data Science, Machine Learning, Deep Learning, and cutting-edge GenAI/Agentic AI frameworks. Project Mentorship: Guide learners through re\u2026",
#   "id": "5806140450",
#   "longitude": 75.9469,
#   "__CLASS__": "Adzuna::API::Response::Job",
#   "redirect_url": "https://www.adzuna.in/land/ad/5806140450?se=4GX2MUOD8RGF5LNal_k3gA&utm_medium=api&utm_source=a1cca52e&v=6D2845F232523FDFE0FDD8CB7BC2306085E389FE",
#   "company": {
#     "display_name": "upGrad",
#     "__CLASS__": "Adzuna::API::Response::Company"
#   },
#   "created": "2026-07-18T18:10:14Z",
#   "title": "Data Science Instructor",
#   "salary_is_predicted": "0",
#   "location": {
#     "__CLASS__": "Adzuna::API::Response::Location",
#     "area": [
#       "India",
#       "Rajasthan",
#       "Jaipur"
#     ],
#     "display_name": "Jaipur, Rajasthan"
#   },
#   "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTgwNjE0MDQ1MCIsInMiOiI0R1gyTVVPRDhSR0Y1TE5hbF9rM2dBIn0.7HnheXGyh8HMJTsJ-cIyxC76eJ1jacp3SqVlUCJHm44",
#   "latitude": 26.7441
# }

# %%
salary_count = sum(1 for r in test_results if r.get("salary_min") is not None)
print(f"Postings with salary_min present: {salary_count} out of {len(test_results)}")
# Out:
# Postings with salary_min present: 3 out of 50

# %%
# Test salary coverage across different countries
for country_code in ["gb", "us"]:
    results = fetch_page(page=1, keyword="data scientist", results_per_page=50, country=country_code)
    salary_count = sum(1 for r in results if r.get("salary_min") is not None)
    print(f"{country_code}: {salary_count} out of {len(results)} postings have salary_min")
# Out:
# gb: 50 out of 50 postings have salary_min
# us: 50 out of 50 postings have salary_min

# %% [markdown]
# ## 5. Insert into MySQL
# Writes each result into the `job_postings` table.

# %%
def insert_postings(results, source="adzuna", country="gb"):
    rows = []
    for r in results:
        rows.append({
            "source": source,
            "country": country,
            "title": r.get("title"),
            "company": r.get("company", {}).get("display_name"),
            "location": r.get("location", {}).get("display_name"),
            "salary_min": r.get("salary_min"),
            "salary_max": r.get("salary_max"),
            "description": r.get("description"),
            "posted_date": r.get("created", "")[:10] or None,
            "raw_json": pyjson.dumps(r),
        })
    df = pd.DataFrame(rows)
    df.to_sql("job_postings", con=engine, if_exists="append", index=False)
    print(f"Inserted {len(df)} rows ({country})")

# %% [markdown]
# ## 6. Full paginated pull
# Loops through multiple pages with rate-limit delay. Adjust `max_pages` and `keywords` as needed.

# %%
countries = ["in", "gb", "us"]
keywords = ["data scientist", "software engineer", "machine learning engineer", "backend developer"]
max_pages = 10

for country_code in countries:
    for kw in keywords:
        for page in range(1, max_pages + 1):
            try:
                results = fetch_page(page=page, keyword=kw, results_per_page=50, country=country_code)
                if not results:
                    break
                insert_postings(results, source="adzuna", country=country_code)
                time.sleep(1)
            except Exception as e:
                print(f"Error on {country_code}/{kw} page {page}: {e}")
                time.sleep(5)
# Out:
# Error on in/data scientist page 1: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Science Instructor', 'company': 'upGrad', 'location': 'Jaipur, Rajasthan', 'salary_min': None, 'salary_max': None, 'description': 'Data Science Instructor (Jaipur) upGrad is expanding its Offline Learning Centres , and we are looking for a dynamic Data Science Instructor in Jaipu ... (202 characters truncated) ... ssions in Data Science, Machine Learning, Deep Learning, and cutting-edge GenAI/Agentic AI frameworks. Project Mentorship: Guide learners through re…', 'posted_date': '2026-07-18', 'raw_json': '{"description": "Data Science Instructor (Jaipur) upGrad is expanding its Offline Learning Centres , and we are looking for a dynamic Data Science In ... (1064 characters truncated) ... 26.7441, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZXNLNE4wT0Q4UkdGNUxOYWxfazNnQSIsImkiOiI1ODA2MTQwNDUwIn0.DoT9SpiqYjyYm2D_8mp67-TnuD9zYDli7oWJhPJxp74"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Science Instructor', 'company': 'upGrad', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'Data Science & AI Instructor upGrad is expanding its Offline Learning Centres , and we are looking for a dynamic Data Science Instructor who is well- ... (202 characters truncated) ... essions: Conduct engaging, in-person lectures and hands-on training sessions in Data Science, Machine Learning, Deep Learning, and cutting-edge GenA…', 'posted_date': '2026-07-03', 'raw_json': '{"created": "2026-07-03T17:37:09Z", "title": "Data Science Instructor", "salary_is_predicted": "0", "location": {"area": ["India"], "__CLASS__": "Adz ... (986 characters truncated) ... n-person lectures and hands-on training sessions in Data Science, Machine Learning, Deep Learning, and cutting-edge GenA\\u2026", "id": "5786785503"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Science Instructor', 'company': 'upGrad', 'location': 'Jabalpur, Madhya Pradesh', 'salary_min': None, 'salary_max': None, 'description': 'Job Title: Data Science Instructor – Offline Learning Centres Location: Jabalpur, Madhya Pradesh Working Days: 6 (Monday – Saturday) About upGrad Fou ... (202 characters truncated) ... , bootcamps, and doctorates for working professionals. Through its B2B arm, upGrad also provides enterprise training, recruitment, and staffing serv…', 'posted_date': '2026-07-18', 'raw_json': '{"longitude": 79.90535, "__CLASS__": "Adzuna::API::Response::Job", "redirect_url": "https://www.adzuna.in/land/ad/5806136048?se=esK4N0OD8RGF5LNal_k3g ... (1097 characters truncated) ... for working professionals. Through its B2B arm, upGrad also provides enterprise training, recruitment, and staffing serv\\u2026", "id": "5806136048"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Part time Data Science Instructor', 'company': 'upGrad', 'location': 'Chandigarh, India', 'salary_min': None, 'salary_max': None, 'description': 'Part-Time Data Science & AI Instructor (Chandigarh) upGrad is expanding its Offline Learning Centres , and we are looking for a dynamic, part-time Da ... (202 characters truncated) ... ious students and working professionals in a classroom setting, this is the perfect role for you! Type: Part-Time Location: Chandigarh (In-person cl…', 'posted_date': '2026-07-03', 'raw_json': '{"description": "Part-Time Data Science & AI Instructor (Chandigarh) upGrad is expanding its Offline Learning Centres , and we are looking for a dyna ... (1111 characters truncated) ... t_time", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc4Njc4NTIyMiIsInMiOiJlc0s0TjBPRDhSR0Y1TE5hbF9rM2dBIn0.HonecvtIsIvLOsFU1U6bxanVJ8KNqlmv9vs-KHThb5c"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Assistant Professor of Computer Science (Data Science, AI - ML, Cyber Security)', 'company': 'Ganpat University Goa', 'location': 'Goa, India', 'salary_min': None, 'salary_max': None, 'description': 'Designation: Assistant Professor - Computer Science (Data Science, AI - ML, Cyber Security) Job Description 1. Teaching & Lear ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 2: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Hexaconcepts  Pvt. Ltd.', 'location': 'Bangalore, Karnataka', 'salary_min': 800000.0, 'salary_max': 2000000.0, 'description': 'Client : A fast growing data-science company, serving clients across industries and geographies in the BFSI domain Position: Data Scientist Experienc ... (202 characters truncated) ... ence in Banking or with NBFCs is mandatory Responsibilities: a) Model Development & Deployment: Develop, validate, and deploy predictive models usin…', 'posted_date': '2026-04-23', 'raw_json': '{"salary_min": 800000, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoiektONlBVT0Q4UkdYLUtDYUxtQ2VNZyIsImkiOiI1NzA3NzA5MzM0In0.t8tJskej1tHtDF_6G8CX5tZrVHSrVP6 ... (1071 characters truncated) ... salary_is_predicted": "0", "id": "5707709334", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Hexaconcepts  Pvt. Ltd."}}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Slate Technologies', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Position Vacant: Senior Data Scientist Company Profile At Slate Technologies we are bringing fresh minds and tools to the world of Smart Buildings, S ... (202 characters truncated) ... me to life. Better decisions happen in construction when you have better context, without context stakeholders are unable to see the right informati…', 'posted_date': '2026-07-15', 'raw_json': '{"salary_is_predicted": "0", "id": "5801068336", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Slate Technologies"}, "_ ... (961 characters truncated) ... NiJ9.eyJzIjoiektONlBVT0Q4UkdYLUtDYUxtQ2VNZyIsImkiOiI1ODAxMDY4MzM2In0.B_etxzUYe2TNBwBHTCtn7nlMQ8a5QJCDl1SqjykrCOs", "created": "2026-07-15T15:37:44Z"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Fusemachines', 'location': 'Pune, Maharashtra', 'salary_min': None, 'salary_max': None, 'description': 'About Fusemachines Fusemachines is a leading AI strategy, talent, and education services provider. Founded by Sameer Maskey Ph.D., Adjunct Associate  ... (202 characters truncated) ... l-time employees, Fusemachines brings global AI expertise to transform companies worldwide. Founded in 2013, Fusemachines is a global provider of en…', 'posted_date': '2026-07-09', 'raw_json': '{"description": "About Fusemachines Fusemachines is a leading AI strategy, talent, and education services provider. Founded by Sameer Maskey Ph.D., A ... (1023 characters truncated) ... 16:41Z", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc5NDE5MjYxNCIsInMiOiJ6S042UFVPRDhSR1gtS0NhTG1DZU1nIn0.0ezj9r3e_oT4uAJaB4eLL99kjge_QU4uhQ0uw4AibEM"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'The Nielsen Company', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Job Description Role Overview As a Hybrid Data Scientist you will sit at the intersection of high-scale data pipelining and advanced statistical meth ... (202 characters truncated) ... and Machine Learning models that quantify the lift of Digital media over a Linear TV baseline. Key Responsibilities 1. Advanced Statistical Modeling…', 'posted_date': '2026-07-17', 'raw_json': '{"created": "2026-07-17T18:58:09Z", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTgwNDkwODkwMiIsInMiOiJ6S042UFVPRDhSR1gtS0NhTG1DZU1nIn0.NTAisyEDF9CZ8Y7q1r ... (968 characters truncated) ... ", "id": "5804908902", "company": {"display_name": "The Nielsen Company", "__CLASS__": "Adzuna::API::Response::Company"}, "salary_is_predicted": "0"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Bosch Group', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Job Description Job Description Education and Work Experience Requirements: 5 to 8 years of experience as Data Scientist or GenAI specialist 2 to 3 y ... (202 characte ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 3: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Rulesiq', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Job Description: Position Title: Data Scientist/Machine Learning Engineer Experience : - Minimum 3 Years Location: Remote Employment Type: Full-Time  ... (202 characters truncated) ... data science, and software engineering, coupled with the ability to design and implement end-to-end systems. This role involves working with cutting…', 'posted_date': '2025-11-20', 'raw_json': '{"location": {"__CLASS__": "Adzuna::API::Response::Location", "display_name": "Bangalore, Karnataka", "area": ["India", "Karnataka", "Bangalore"]}, " ... (1025 characters truncated) ... \u2026", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTUwMzgzODIwOSIsInMiOiJFb3JqUTBPRDhSR0I0TUUwVy1tcDN3In0.ARM1xaARsg1S5Jm-lwDd-HIrJPoFJKY0ybV_FRadoiA"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Ad Astra Consultants', 'location': 'Bangalore, Karnataka', 'salary_min': 500000.0, 'salary_max': 1500000.0, 'description': 'In this role, we are looking for: A problem-solving mindset with the ability to understand business challenges and how to apply your analytics expert ... (202 characters truncated) ... dual excited by innovation and new technology and eager to finds ways to employ these innovations in practice. A team mentality, empowered by the ab…', 'posted_date': '2020-11-22', 'raw_json': '{"description": "In this role, we are looking for: A problem-solving mindset with the ability to understand business challenges and how to apply your ... (1033 characters truncated) ... "Karnataka", "Bangalore"]}, "title": "Data Scientist", "redirect_url": "https://www.adzuna.in/details/1837542039?utm_medium=api&utm_source=a1cca52e"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Officeworks', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Why this role exists: The Data Scientist is a key member of the Advanced Analytics team, responsible for the end-to-end delivery of advanced analytic ... (202 characters truncated) ... ization. Where you will make a difference: In this role you will: Data Science and Model Development: Develop, test and improve statistical, machine…', 'posted_date': '2026-07-01', 'raw_json': '{"description": "Why this role exists: The Data Scientist is a key member of the Advanced Analytics team, responsible for the end-to-end delivery of  ... (954 characters truncated) ... "Karnataka", "Bangalore"]}, "title": "Data Scientist", "redirect_url": "https://www.adzuna.in/details/5782877685?utm_medium=api&utm_source=a1cca52e"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Ikrux Solutions  Private Limited', 'location': 'Pune, Maharashtra', 'salary_min': None, 'salary_max': None, 'description': 'We are seeking a highly skilled and motivated AI/ML Engineer with expertise in Natural Language Processing (NLP), Machine Learning, and Data Analytic ... (202 characters truncated) ... utcomes. Candidates must hold a Bachelor s, Master s, or Ph.D. in Computer Science, Mathematics, Statistics, or a related field and have hands-on ex…', 'posted_date': '2026-06-12', 'raw_json': '{"longitude": 73.84735, "latitude": 18.5062, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc2MDc0ODE0MSIsInMiOiJFb3JqUTBPRDhSR0I0TUUwVy1tcDN3In0.nay0q2-dg ... (1013 characters truncated) ... , "__CLASS__": "Adzuna::API::Response::Company"}, "category": {"label": "IT Jobs", "tag": "it-jobs", "__CLASS__": "Adzuna::API::Response::Category"}}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'PublicVibe', 'location': 'Hyderabad, Telangana', 'salary_min': 100000.0, 'salary_max': 300000.0, 'description': 'Hi Candidates, Greetings From Publicvibe  We are Hiring NLP Engineers/ Data scientists in between 0.6 to 2.5 Years of Experience for our Hyderabad lo ... (60 cha ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 4: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Amgen', 'location': 'Hyderabad, Telangana', 'salary_min': None, 'salary_max': None, 'description': "About Amgen Join Amgen's Mission of Serving Patients At Amgen, if you feel like you're part of something bigger, it's because you are. Our shared mis ... (202 characters truncated) ... ur therapeutic areas -Oncology, Inflammation, General Medicine, and Rare Disease- we reach millions of patients each year. As a member of the Amgen …", 'posted_date': '2025-05-11', 'raw_json': '{"location": {"area": ["India", "Telangana", "Hyderabad"], "display_name": "Hyderabad, Telangana", "__CLASS__": "Adzuna::API::Response::Location"}, " ... (998 characters truncated) ... "5193892372", "salary_is_predicted": "0", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Amgen"}, "longitude": 78.50806}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Cardinal Health', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'Data Scientist Headquartered in Dublin, Ohio, Cardinal Health, Inc. (NYSE: CAH) is a global, integrated healthcare services and products company conn ... (202 characters truncated) ... s in nearly 60 countries, Cardinal Health ranks among the top 20 on the Fortune 500. Department Overview AI & Data Science team builds analytics and…', 'posted_date': '2026-07-16', 'raw_json': '{"location": {"area": ["India"], "display_name": "India", "__CLASS__": "Adzuna::API::Response::Location"}, "description": "Data Scientist Headquarter ... (917 characters truncated) ... a52e", "id": "5802319401", "salary_is_predicted": "0", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Cardinal Health"}}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Arahas Technologies', 'location': 'India', 'salary_min': 800000.0, 'salary_max': 1200000.0, 'description': 'We are seeking a skilled Data Scientist with min 3 years of experience to join our team in Gurugram. This role will also require travelling within In ... (202 characters truncated) ... rtise in ETL (Extract, Transform, Load) processes is required. Responsibilities: Analyze complex datasets to extract valuable insights and identify …', 'posted_date': '2025-02-23', 'raw_json': '{"created": "2025-02-23T04:23:27Z", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoid09mNlNFT0Q4UkdGTWE2YldIenRoUSIsImkiOiI1MDYwODY4NjY5In0.acjjUjqTK5ugswgRQD ... (996 characters truncated) ... "0", "redirect_url": "https://www.adzuna.in/details/5060868669?utm_medium=api&utm_source=a1cca52e", "contract_time": "full_time", "id": "5060868669"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Antworks Solutions India Private Limited', 'location': 'Chennai, Tamil Nadu', 'salary_min': None, 'salary_max': None, 'description': "Required Qualifications Education Bachelor's or Master's degree in Computer Science, Data Science, Statistics, Mathematics, or a related field. Exper ... (202 characters truncated) ... ding experience. Experience with machine learning frameworks such as TensorFlow and PyTorch. Strong knowledge of NLP libraries and tools such as Spa…", 'posted_date': '2026-06-11', 'raw_json': '{"adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoid09mNlNFT0Q4UkdGTWE2YldIenRoUSIsImkiOiI1NzU5MjgzMjg5In0.0CPBGpxI8becrbYlvEH3zE6-jglNQ3qu3jvbgvyi7x8", "catego ... (1028 characters truncated) ... any"}, "salary_is_predicted": "0", "redirect_url": "https://www.adzuna.in/details/5759283289?utm_medium=api&utm_source=a1cca52e", "id": "5759283289"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Ecolab', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'As a Data Scientist, you will design, build, and deploy advanced data-driven and AI-powered solutions that address complex business challenges. This  ... (202 characters truncated) ... ce in Data Science and M ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 5: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Dori AI', 'location': 'Bangalore, Karnataka', 'salary_min': 100000.0, 'salary_max': 2000000.0, 'description': 'Dori AI enables enterprises with AI-powered video analytics to significantly increase human productivity and improve process compliance. We leverage  ... (202 characters truncated) ... ime-to-value, time-to-market, security and scalability across a range of use cases. Capture visual data across multiple sites, leverage AI  Computer…', 'posted_date': '2022-05-05', 'raw_json': '{"created": "2022-05-05T05:56:22Z", "salary_is_predicted": "0", "id": "3104612698", "__CLASS__": "Adzuna::API::Response::Job", "company": {"__CLASS__ ... (1025 characters truncated) ...  and scalability across a range of use cases. Capture visual data across multiple sites, leverage AI  Computer\\u2026", "contract_time": "full_time"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Yes Property', 'location': 'Bangalore, Karnataka', 'salary_min': 300000.0, 'salary_max': 500000.0, 'description': '*Work with stakeholders throughout the organization to identify opportunities for leveraging company data to drive business solutions. *Mine and anal ... (202 characters truncated) ...  data gathering techniques. *Develop custom data models and algorithms to apply to data sets. *Use predictive modeling to increase and optimize cust…', 'posted_date': '2019-06-05', 'raw_json': '{"salary_max": 500000, "__CLASS__": "Adzuna::API::Response::Job", "category": {"tag": "it-jobs", "__CLASS__": "Adzuna::API::Response::Category", "lab ... (1024 characters truncated) ... OiJIUzI1NiJ9.eyJpIjoxMTcxNTA3NzU5LCJzIjoiOHZxd1RVT0Q4UkdCNE1FMFctbXAzdyJ9.gXUT5oXk6H5qzJCpH8w_SYFoJAey8yKBvkjgF6LppoE", "contract_time": "full_time"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'IQVIA', 'location': 'Kochi, Ernakulam', 'salary_min': 400000.0, 'salary_max': 1000000.0, 'description': 'Job Description Summary Skill sets in Job Profile 1)Machine learning development using Python or Scala Spark 2)Knowledge of multiple ML algorithms li ... (202 characters truncated) ... experience 2)Cloud service (AWS, Cloudera), SAAS, PAAS 3)Big data tools and framework 4)SQL experience Skills:- Data Science, Python, Spark and scala', 'posted_date': '2020-12-26', 'raw_json': '{"longitude": 76.24637, "contract_time": "full_time", "latitude": 9.98011, "description": "Job Description Summary Skill sets in Job Profile 1)Machin ... (1058 characters truncated) ... 0", "id": 1901122601, "company": {"display_name": "IQVIA", "__CLASS__": "Adzuna::API::Response::Company"}, "__CLASS__": "Adzuna::API::Response::Job"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Yottaasys AI LLC', 'location': 'Bangalore, Karnataka', 'salary_min': 0.0, 'salary_max': 2000000.0, 'description': 'We are a US Headquartered Product Company looking to Hire a few Passionate Deep Learning and Computer Vision Team Players with 2-5 years of experienc ... (202 characters truncated) ... s, Statistics and pattern recognition. Then u r the right fit for this position. Skills:- Data Science, R Programming, Python, Machine Learning (ML)…', 'posted_date': '2021-08-10', 'raw_json': '{"title": "Data Scientist", "redirect_url": "https://www.adzuna.in/details/2373548974?utm_medium=api&utm_source=a1cca52e", "location": {"display_name ... (1029 characters truncated) ...  recognition. Then u r the right fit for this position. Skills:- Data Science, R Programming, Python, Machine Learning (ML)\\u2026", "salary_min": 0}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Multi Recruit', 'location': 'Bangalore, Karnataka', 'salary_min': 3000000.0, 'salary_max': 4000000.0, 'description': "You'd have to set up your own shop, work with design customers to find generalizable use cases, and build them out. Ability to collaborate with cross ... (202 charac ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 6: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Webkit24', 'location': 'Kolkata, West Bengal', 'salary_min': None, 'salary_max': None, 'description': 'Key Responsibilities Analyze large datasets to discover trends and patterns Build predictive models and machine-learning algorithms Collaborate with  ... (202 characters truncated) ... g tools like Power BI, Tableau, or Python libraries Maintain documentation of processes, models, and project results Required Skills & Qualification…', 'posted_date': '2026-06-26', 'raw_json': '{"id": "5777073722", "description": "Key Responsibilities Analyze large datasets to discover trends and patterns Build predictive models and machine- ... (996 characters truncated) ... k4WZA5vF9LjKiV3_0GpwjNrdEzF25iI", "company": {"display_name": "Webkit24", "__CLASS__": "Adzuna::API::Response::Company"}, "salary_is_predicted": "0"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'ADP Private Limited', 'location': 'Hyderabad, Telangana', 'salary_min': None, 'salary_max': None, 'description': 'Minimum experience of 5 years with very good proficiency in Python and libraries like Pandas, Numpy, Sklearn etc., Good knowledge of ML models develo ... (202 characters truncated) ... ledge of NLP and related frameworks. Building solutions with GenAI and various LLM models for specific use cases. Experience in data preparation, cl…', 'posted_date': '2026-07-01', 'raw_json': '{"company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "ADP Private Limited"}, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoieGktZVVrT0 ... (1007 characters truncated) ... "], "__CLASS__": "Adzuna::API::Response::Location", "display_name": "Hyderabad, Telangana"}, "latitude": 17.40275, "created": "2026-07-01T07:13:47Z"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Infinium Associate', 'location': 'Delhi, India', 'salary_min': 4000000.0, 'salary_max': 4500000.0, 'description': 'DataHavn IT Solutions is a company that specializes in big data and cloud computing, artificial intelligence and machine learning, application develo ... (202 characters truncated) ... Role: As a Data Scientist specializing in Google Cloud, you will play a pivotal role in driving data-driven decision-making and innovation within ou…', 'posted_date': '2025-11-02', 'raw_json': '{"title": "Data Scientist", "latitude": 28.62523, "created": "2025-11-02T06:52:09Z", "id": "5476310343", "longitude": 77.224601, "salary_is_predicted ... (1058 characters truncated) ...  a Data Scientist specializing in Google Cloud, you will play a pivotal role in driving data-driven decision-making and innovation within ou\\u2026"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Archcorp Architectural Engineering', 'location': 'Mumbai, Maharashtra', 'salary_min': 500000.0, 'salary_max': 1500000.0, 'description': 'Main Responsibilities: Work closely with your business to identify issues and use data to propose solutions for effective decision making Build algor ... (202 characters truncated) ... gorithms and statistics: regression, simulation, scenario analysis, modeling, clustering, decision trees, neural networks, etc Querying databases an…', 'posted_date': '2022-08-17', 'raw_json': '{"salary_is_predicted": "0", "category": {"__CLASS__": "Adzuna::API::Response::Category", "tag": "it-jobs", "label": "IT Jobs"}, "redirect_url": "htt ... (1050 characters truncated) ...  and statistics: regression, simulation, scenario analysis, modeling, clustering, decision trees, neural networks, etc Querying databases an\\u2026"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Chubb Business Services India Private Limited', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': 'Address model drift and performance of business requirements as part of recurring operations, drive quantitative model ma ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 7: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Srijan Technologies', 'location': 'India', 'salary_min': 500000.0, 'salary_max': 2500000.0, 'description': 'Job Responsibilities:- Develop robust, scalable and maintainable machine learning models to answer business problems against large data sets. Build m ... (202 characters truncated) ... eering and organize experiments in conjunction with best practices. Benchmark, apply, and test algorithms against success metrics. Interpret the res…', 'posted_date': '2022-04-05', 'raw_json': '{"redirect_url": "https://www.adzuna.in/details/3025811218?utm_medium=api&utm_source=a1cca52e", "salary_min": 500000, "location": {"__CLASS__": "Adzu ... (996 characters truncated) ... and test algorithms against success metrics. Interpret the res\\u2026", "created": "2022-04-05T05:16:08Z", "salary_max": 2500000, "id": "3025811218"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'TitletownTech', 'location': 'Ajmer, Rajasthan', 'salary_min': None, 'salary_max': None, 'description': 'GenLogs is a transportation-technology company building the next generation of truck intelligence. Through a nationwide network of sensors and propri ... (202 characters truncated) ... , combat freight fraud and cargo theft, and provide near-instantaneous visibility into commercial motor vehicle activity across major freight corrid…', 'posted_date': '2026-06-22', 'raw_json': '{"latitude": 26.52495, "id": "5772432268", "description": "GenLogs is a transportation-technology company building the next generation of truck intel ... (1045 characters truncated) ... ntract_time": "full_time", "salary_is_predicted": "0", "redirect_url": "https://www.adzuna.in/details/5772432268?utm_medium=api&utm_source=a1cca52e"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Oceaneering', 'location': 'Chandigarh, India', 'salary_min': None, 'salary_max': None, 'description': 'Job Description The Data Scientists will develop integrated Machine Learning and/or Deep Learning based solutions on products that address customer n ... (202 characters truncated) ... ring’s next generation systems. Responsibilities Work with minimal supervision to develop robust computer vision algorithms that will be deployed in…', 'posted_date': '2026-06-30', 'raw_json': '{"longitude": 76.76094, "category": {"__CLASS__": "Adzuna::API::Response::Category", "label": "Engineering Jobs", "tag": "engineering-jobs"}, "compan ... (1068 characters truncated) ... sion algorithms that will be deployed in\\u2026", "contract_type": "permanent", "title": "Data Scientist", "__CLASS__": "Adzuna::API::Response::Job"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Topcoder', 'location': 'Noida, Ghaziabad', 'salary_min': None, 'salary_max': None, 'description': 'Customer is specifically looking for involvement in model development, descriptive, predictive, and prescriptive modeling, supervised and unsupervise ... (202 characters truncated) ... ) rather than primarily BI, SAP, or AI architecture work. What you’ll do The ideal candidate will be responsible for analyzing large datasets to ext…', 'posted_date': '2026-04-01', 'raw_json': '{"adref": "eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRHE5M1YwT0Q4Ukc2NGJwbS02Qnc2dyIsImkiOiI1Njg0NDQ5NTU4In0.vILfANeb2QPbnU_URY39nhEz7SxSmk67--gLPaFZjSw", "compan ... (1010 characters truncated) ... re work. What you\\u2019ll do The ideal candidate will be responsible for analyzing large datasets to ext\\u2026", "created": "2026-04-01T01:56:34Z"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Scientist', 'company': 'Kaleidofin', 'location': 'Chennai, Tamil Nadu', 'salary_min': 500000.0, 'salary_max': 3000000.0, 'description': 'Key Responsibilities: Partnering with clients and internal business owners (product, marketing, edit, etc.) to understand needs and develop models an ... (202 characters truncated) ... rement needs and c ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 8: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'AVP / VP – Collections Strategy & Operations | CAAS', 'company': 'MetaMorph', 'location': 'Mumbai, Maharashtra', 'salary_min': None, 'salary_max': None, 'description': 'Job Description – AVP / VP Collections Location: Mumbai Experience: 10 Years About the Role We are looking for an experienced Collections Leader to d ... (202 characters truncated) ...  decision-making, and managing agency networks across geographies. This role requires a strong blend of collections expertise, strategic thinking, s…', 'posted_date': '2026-06-20', 'raw_json': '{"description": "Job Description \\u2013 AVP / VP Collections Location: Mumbai Experience: 10 Years About the Role We are looking for an experienced  ... (1147 characters truncated) ... iJIUzI1NiJ9.eyJzIjoiQUxOalhFT0Q4UkdJSG9XU3h2OEdyUSIsImkiOiI1NzcwNjIyOTU2In0._FN2wqCxEt3F8T6zNlkN7PvrLH-QdbhLya8wYwnKyMI", "salary_is_predicted": "0"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Faculty - Computer Science', 'company': 'Westford Global Education', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'Company Description Westford Global Education, established in 2009 and headquartered in the Isle of Man, delivers flexible, internationally recognize ... (202 characters truncated) ... rd Abroad, and Westford for Business, the organization supports learners from foundation to doctorate level. Its offerings span live and self-paced …', 'posted_date': '2026-06-25', 'raw_json': '{"salary_is_predicted": "0", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc3NTEzNzAxMCIsInMiOiJBTE5qWEVPRDhSR0lIb1dTeHY4R3JRIn0.pEqdNIZP351NwAXndg8C1AY0t ... (1050 characters truncated) ... ion supports learners from foundation to doctorate level. Its offerings span live and self-paced \\u2026", "__CLASS__": "Adzuna::API::Response::Job"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Assistant Professor', 'company': 'UPES School of Computer Science', 'location': 'Dehradun, Uttarakhand', 'salary_min': None, 'salary_max': None, 'description': 'UPES, Dehradun ( https://www.upes.ac.in ) is inviting applications for the position of Assistant Professors in the School of Computer Science . Respo ... (202 characters truncated) ... e to the department and university. Preferred Areas of Expertise : Programming, DSA, DBMS, Software Engineering, Computer Organization, Theory of Co…', 'posted_date': '2026-06-04', 'raw_json': '{"latitude": 30.3541, "created": "2026-06-04T16:45:32Z", "location": {"__CLASS__": "Adzuna::API::Response::Location", "display_name": "Dehradun, Utta ... (1104 characters truncated) ... bJFa46c06jSa2sCaZBSc_q-ziwPkzsWozlTk", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "UPES School of Computer Science"}}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Graphic Designer (Social Media & Motion Graphics)', 'company': 'Boston Institute of Analytics', 'location': 'Mumbai, Maharashtra', 'salary_min': None, 'salary_max': None, 'description': 'Location: Mumbai (On-site) Company: Boston Institute of Analytics Salary: Up to ₹4 LPA About Boston Institute of Analytics The Boston Institute of An ... (202 characters truncated) ... r a creative graphic designer who can help strengthen our digital brand presence through impactful visual communication. Role Overview We are seekin…', 'posted_date': '2026-07-18', 'raw_json': '{"id": "5806135476", "description": "Location: Mumbai (On-site) Company: Boston Institute of Analytics Salary: Up to \\u20b94 LPA About Boston Instit ... (1153 characters truncated) ... PHFhW5RR2g", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Boston Institute of Analytics"}, "salary_is_predicted": "0"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Technical Account Manager (Strategic Accounts)', 'company': 'TrueFoundry', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': "About TrueFoundry Every production AI system ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 9: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Director Data Science', 'company': 'Amgen', 'location': 'Hyderabad, Telangana', 'salary_min': None, 'salary_max': None, 'description': 'Career Category Research Job Description HOW MIGHT YOU DEFY IMAGINATION? If you feel like you’re part of something bigger, it’s because you are. At A ... (202 characters truncated) ... ng, manufacturing, and delivering ever-better products that reach over 10 million patients worldwide. It’s time for a career you can be proud of. Jo…', 'posted_date': '2026-04-06', 'raw_json': '{"location": {"display_name": "Hyderabad, Telangana", "__CLASS__": "Adzuna::API::Response::Location", "area": ["India", "Telangana", "Hyderabad"]}, " ... (1072 characters truncated) ... , "tag": "it-jobs"}, "redirect_url": "https://www.adzuna.in/details/5690845213?utm_medium=api&utm_source=a1cca52e", "title": "Director Data Science"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Senior Data Scientist', 'company': 'Kvc Consultants Ltd', 'location': 'Bangalore, Karnataka', 'salary_min': None, 'salary_max': None, 'description': "We are seeking a highly skilled and experienced Senior Data Scientist to join KVC Consultants Ltd. In this role, you'll focus on developing and imple ... (202 characters truncated) ... oration with other data scientists and engineers to create innovative data solutions. Roles and Responsibilities: Data Science & Model Development: …", 'posted_date': '2026-06-19', 'raw_json': '{"id": "5768790875", "__CLASS__": "Adzuna::API::Response::Job", "description": "We are seeking a highly skilled and experienced Senior Data Scientist ... (971 characters truncated) ... OSoLVcRY4rM88_fqfSxU", "company": {"__CLASS__": "Adzuna::API::Response::Company", "display_name": "Kvc Consultants Ltd"}, "salary_is_predicted": "0"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Head Data Science', 'company': 'REDCLIFFE LIFETECH PRIVATE LIMITED', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'As the Head of Data Science at Redcliffe Labs your role will involve leading the organizations advanced analytics and AI initiatives You will be resp ... (202 characters truncated) ... d boardlevel discussions influencing strategic direction and identifying opportunities where AI ML can deliver measurable impact Additionally you wi…', 'posted_date': '2026-06-18', 'raw_json': '{"salary_is_predicted": "0", "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTc2NzM5Nzc2MCIsInMiOiItRjVnWVVPRDhSR0lIb1dTeHY4R3JRIn0.eqKu4JZk0qG2wpmQSCgKyGc-Z ... (939 characters truncated) ... ction and identifying opportunities where AI ML can deliver measurable impact Additionally you wi\\u2026", "__CLASS__": "Adzuna::API::Response::Job"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Sr Data Scientist', 'company': 'Petras solutions', 'location': 'Pune, Maharashtra', 'salary_min': 2500000.0, 'salary_max': 4000000.0, 'description': 'Job Description Our Media Measurement team uses state-of-the-art technologies and rigorous methods to track who is watching what, where, and how they ... (202 characters truncated) ...  content on more channels, and through more devices, than ever before, we are proud to provide a full view on media consumption. As Data Scientist y…', 'posted_date': '2026-06-26', 'raw_json': '{"title": "Sr Data Scientist", "created": "2026-06-26T14:57:28Z", "latitude": 18.5062, "id": "5777486802", "longitude": 73.84735, "salary_is_predicte ... (1076 characters truncated) ...  on more channels, and through more devices, than ever before, we are proud to provide a full view on media consumption. As Data Scientist y\\u2026"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Data Science with Pyspark', 'company': 'Linkedin', 'location': 'India', 'salary_min': None, 'salary_max': None, 'description': 'As a Data Scientist with expertise in Pyspark you will be responsible for the following key responsibilities Analyze largescale datasets using PySpar ... (202 charact ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/data scientist page 10: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'in', 'title': 'Principal Data Scientist', 'company': 'Benovymed Healthcare', 'location': 'Jaipur, Rajasthan', 'salary_min': None, 'salary_max': None, 'description': 'Key Responsibilities Develop and implement advanced machine learning models, statistical algorithms, and predictive analytics solutions to support bu ... (202 characters truncated) ... ate insights to non-technical stakeholders. Work closely with data engineering teams to integrate data from multiple sources into unified data platf…', 'posted_date': '2026-05-24', 'raw_json': '{"id": "5739309314", "__CLASS__": "Adzuna::API::Response::Job", "category": {"label": "IT Jobs", "tag": "it-jobs", "__CLASS__": "Adzuna::API::Respons ... (1010 characters truncated) ... pIjoiNTczOTMwOTMxNCIsInMiOiJvTW96WmtPRDhSR0I0TUUwVy1tcDN3In0.-nzlupmuGlkfcozGORmBDHB-JuMr-6ZHxf_NVkw-yD8", "latitude": 26.7441, "longitude": 75.9469}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Principal Data Scientist', 'company': 'Benovymed Healthcare', 'location': 'Indore, Madhya Pradesh', 'salary_min': None, 'salary_max': None, 'description': 'Key Responsibilities Develop and implement advanced machine learning models, statistical algorithms, and predictive analytics solutions to support bu ... (202 characters truncated) ... ate insights to non-technical stakeholders. Work closely with data engineering teams to integrate data from multiple sources into unified data platf…', 'posted_date': '2026-05-24', 'raw_json': '{"title": "Principal Data Scientist", "redirect_url": "https://www.adzuna.in/details/5739309346?utm_medium=api&utm_source=a1cca52e", "location": {"ar ... (1021 characters truncated) ... ghts to non-technical stakeholders. Work closely with data engineering teams to integrate data from multiple sources into unified data platf\\u2026"}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Principal Data Scientist', 'company': 'Benovymed Healthcare', 'location': 'Chennai, Tamil Nadu', 'salary_min': None, 'salary_max': None, 'description': 'Key Responsibilities Develop and implement advanced machine learning models, statistical algorithms, and predictive analytics solutions to support bu ... (202 characters truncated) ... ate insights to non-technical stakeholders. Work closely with data engineering teams to integrate data from multiple sources into unified data platf…', 'posted_date': '2026-05-24', 'raw_json': '{"id": "5739309313", "__CLASS__": "Adzuna::API::Response::Job", "category": {"label": "IT Jobs", "__CLASS__": "Adzuna::API::Response::Category", "tag ... (1016 characters truncated) ... joiNTczOTMwOTMxMyIsInMiOiJvTW96WmtPRDhSR0I0TUUwVy1tcDN3In0.XgKnImF2-2QDWCAxUBcoyMU36T8pnkpcwVKU2-_720o", "latitude": 13.06041, "longitude": 80.24963}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Principal Data Scientist', 'company': 'Benovymed Healthcare', 'location': 'Lucknow, Uttar Pradesh', 'salary_min': None, 'salary_max': None, 'description': 'Key Responsibilities Develop and implement advanced machine learning models, statistical algorithms, and predictive analytics solutions to support bu ... (202 characters truncated) ... ate insights to non-technical stakeholders. Work closely with data engineering teams to integrate data from multiple sources into unified data platf…', 'posted_date': '2026-05-24', 'raw_json': '{"created": "2026-05-24T06:57:09Z", "salary_is_predicted": "0", "category": {"__CLASS__": "Adzuna::API::Response::Category", "tag": "it-jobs", "label ... (1020 characters truncated) ... osely with data engineering teams to integrate data from multiple sources into unified data platf\\u2026", "longitude": 80.8897, "latitude": 26.8677}'}, {'source': 'adzuna', 'country': 'in', 'title': 'Senior Data Scientist', 'company': 'WyngCommerce', 'location': 'Bangalore, Karnataka', 'salary_min': 1800000.0, 'salary_max': 2500000.0, 'description': 'WyngCommerce is building state of the art AI software for the Global Consumer Brands & Retailers to enabl ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on in/software engineer page 1: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on gb/backend developer page 7: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'gb', 'title': 'Software Engineer, Platform - Oxford, United Kingdom', 'company': 'Speechify', 'location': 'Oxford, Oxfordshire', 'salary_min': 49240.89, 'salary_max': 49240.89, 'description': 'The mission of Speechify is to make sure that reading is never a barrier to learning. Over 50 million people use Speechify’s text-to-speech products  ... (202 characters truncated) ... ude its iOS app, Android App, Mac App, Chrome Extension, and Web App. Google recently named Speechify the Chrome Extension of the Year and Apple nam…', 'posted_date': '2026-05-13', 'raw_json': '{"adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcyNzk4Njg3NiIsInMiOiJSaUFJdlVTRDhSR0I0TUUwVy1tcDN3In0.F1BKDPN2OCcGniBk4IwgEK5VMyiL7forxhK3tOoRSUE", "descri ... (1137 characters truncated) ... area": ["UK", "South East England", "Oxfordshire", "Oxford"], "display_name": "Oxford, Oxfordshire", "__CLASS__": "Adzuna::API::Response::Location"}}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Senior Frontend Engineer', 'company': 'Halos Body Cams', 'location': 'Belfast, Northern Ireland', 'salary_min': 70000.0, 'salary_max': 80000.0, 'description': 'HALOS is an advanced body camera and cloud software scaleup, working with some of the biggest names in security, services, and law enforcement. At HA ... (205 characters truncated) ... tured. Our team embodies openness, transparency, and a "one team" spirit. We\'re a group of passionate individuals, all working on exciting and impa…', 'posted_date': '2026-05-13', 'raw_json': '{"location": {"area": ["UK", "Northern Ireland", "Belfast"], "__CLASS__": "Adzuna::API::Response::Location", "display_name": "Belfast, Northern Irela ... (1062 characters truncated) ... : 70000, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTcyNzk4MDk2MSIsInMiOiJSaUFJdlVTRDhSR0I0TUUwVy1tcDN3In0.89CJqGwFqLgviKpDwlofS9s5qyPPQa7gCOGZdcvPyss"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Engineer, Platform - Birmingham, United Kingdom', 'company': 'Speechify', 'location': 'Birmingham, West Midlands', 'salary_min': 48927.49, 'salary_max': 48927.49, 'description': 'The mission of Speechify is to make sure that reading is never a barrier to learning. Over 50 million people use Speechify’s text-to-speech products  ... (202 characters truncated) ... ude its iOS app, Android App, Mac App, Chrome Extension, and Web App. Google recently named Speechify the Chrome Extension of the Year and Apple nam…', 'posted_date': '2026-05-01', 'raw_json': '{"title": "Software Engineer, Platform - Birmingham, United Kingdom", "redirect_url": "https://www.adzuna.co.uk/jobs/details/5716225051?utm_medium=ap ... (1133 characters truncated) ... c App, Chrome Extension, and Web App. Google recently named Speechify the Chrome Extension of the Year and Apple nam\\u2026", "salary_min": 48927.49}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Security Engineer', 'company': 'Fortinet', 'location': 'London, UK', 'salary_min': 47409.04, 'salary_max': 47409.04, 'description': 'Description Software Security Engineer - Moorgate office based Join Fortinet, a global cybersecurity pioneer with over two decades of excellence, as  ... (202 characters truncated) ...  seeking an experienced Software Security Engineer to contribute to the success of our rapidly growing business. The FortiDLP platform collects mill…', 'posted_date': '2026-04-01', 'raw_json': '{"description": "Description Software Security Engineer - Moorgate office based Join Fortinet, a global cybersecurity pioneer with over two decades o ... (1067 characters truncated) ... ::Job", "title": "Software Security Engineer", "redirect_url": "https://www.adzuna.co.uk/jobs/details/5685273223?utm_medium=api&utm_source=a1cca52e"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Engineer, Platform - Cambridge, United Kingdom', 'company': 'Speechify', 'location': 'Cambridge, Cambridgeshire', 'salary_min': 49073.62, 'salary_max': 49073.62, 'description': 'The mission of Spee ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on gb/backend developer page 8: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'gb', 'title': 'Backend Engineer - Capital Markets SaaS', 'company': 'Ec1 Partners', 'location': 'London, UK', 'salary_min': 88516.77, 'salary_max': 88516.77, 'description': 'Job Description Role Overview This role focuses on building backend services for a capital markets SaaS platform used by financial institutions to ma ... (202 characters truncated) ... p backend services and APIs Support scalable, high-availability systems Collaborate with product and frontend teams Improve system performance and r…', 'posted_date': '2026-04-19', 'raw_json': '{"location": {"__CLASS__": "Adzuna::API::Response::Location", "area": ["UK", "London"], "display_name": "London, UK"}, "created": "2026-04-19T11:17:3 ... (1090 characters truncated) ... splay_name": "Ec1 Partners"}, "category": {"__CLASS__": "Adzuna::API::Response::Category", "tag": "it-jobs", "label": "IT Jobs"}, "id": "5704447306"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Senior Staff Software Developer', 'company': 'Ocho', 'location': 'Belfast, Northern Ireland', 'salary_min': 90000.0, 'salary_max': 90000.0, 'description': "Senior Staff Software Engineer Belfast | Hybrid | Permanent At a Glance Senior technical leadership role with real influence on architecture and deli ... (202 characters truncated) ... o You'll Work For Our client is a technology organisation building sophisticated data and analytics products at scale. Their engineering team operat…", 'posted_date': '2026-07-09', 'raw_json': '{"redirect_url": "https://www.adzuna.co.uk/jobs/land/ad/5794231707?se=1O7cwkSD8RGF5LNal_k3gA&utm_medium=api&utm_source=a1cca52e&v=EBA34EA50185D2455BB ... (1127 characters truncated) ...  Work For Our client is a technology organisation building sophisticated data and analytics products at scale. Their engineering team operat\\u2026"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Principal Engineer I', 'company': 'Menlo Security', 'location': 'UK', 'salary_min': 76638.86, 'salary_max': 76638.86, 'description': "Menlo Security's mission is enabling the world to connect, communicate and collaborate securely without compromise. COVID-19 has made our mission all ... (202 characters truncated) ... re growing from 400 employees into the next phase of our journey, and we need passionate talent filled with empathy and agility. The right candidate…", 'posted_date': '2026-06-10', 'raw_json': '{"longitude": -0.746479, "redirect_url": "https://www.adzuna.co.uk/jobs/details/5758422612?utm_medium=api&utm_source=a1cca52e", "salary_max": 76638.8 ... (1047 characters truncated) ... , "salary_is_predicted": "1", "category": {"__CLASS__": "Adzuna::API::Response::Category", "tag": "it-jobs", "label": "IT Jobs"}, "id": "5758422612"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Senior Digital Engineer (Java)', 'company': 'Love2Shop', 'location': 'Stanley, Liverpool', 'salary_min': 50558.48, 'salary_max': 50558.48, 'description': "About the Role A Senior Digital Engineer at Love2shop, you will play a key role in designing, building, and maintaining digital products that power o ... (202 characters truncated) ...  for millions of users. You'll be part of a collaborative, cross functional engineering team, contributing to the full development lifecycle: from s…", 'posted_date': '2026-06-23', 'raw_json': '{"category": {"label": "IT Jobs", "tag": "it-jobs", "__CLASS__": "Adzuna::API::Response::Category"}, "id": "5773748554", "__CLASS__": "Adzuna::API::R ... (1231 characters truncated) ... 3drU0Q4UkdGNUxOYWxfazNnQSIsImkiOiI1NzczNzQ4NTU0In0.T7kVcPHj426fqFnrF5_XCBLgr6D_3WwI9nrBK0PZQps", "latitude": 53.408258, "contract_time": "full_time"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Developer - Data Platform & Distributed Systems', 'company': 'Viridien', 'location': 'UK', 'salary_min': 74725.93, 'salary_max': 74725.93, 'description': 'Viridien ( www.viridiengroup.com ) is an advanced technology, digital and Earth data company that pushes t ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error on gb/backend developer page 9: Execution failed on sql 'INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (:source, :country, :title, :company, :location, :salary_min, :salary_max, :description, :posted_date, :raw_json)': (pymysql.err.OperationalError) (1054, "Unknown column 'country' in 'field list'")
# [SQL: INSERT INTO job_postings (source, country, title, company, location, salary_min, salary_max, description, posted_date, raw_json) VALUES (%(source)s, %(country)s, %(title)s, %(company)s, %(location)s, %(salary_min)s, %(salary_max)s, %(description)s, %(posted_date)s, %(raw_json)s)]
# [parameters: [{'source': 'adzuna', 'country': 'gb', 'title': 'iOS Engineer - Swift - London', 'company': 'Photon Group', 'location': 'UK', 'salary_min': 57781.4, 'salary_max': 57781.4, 'description': 'Description Job Title: iOS Engineer Position Overview: An exciting opportunity for a forward-thinking Mobile iOS Developer who thrives on producing c ... (202 characters truncated) ... building, and maintaining iOS applications. Experience in backend APIs is an added advantage. You will collaborate with your team, fostering a cultu…', 'posted_date': '2024-07-31', 'raw_json': '{"company": {"display_name": "Photon Group", "__CLASS__": "Adzuna::API::Response::Company"}, "adref": "eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNDgwMjQ5NTczNCIsI ... (1046 characters truncated) ... APIs is an added advantage. You will collaborate with your team, fostering a cultu\\u2026", "created": "2024-07-31T15:01:58Z", "salary_max": 57781.4}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Engineering Co-op', 'company': 'Moment Energy', 'location': 'UK', 'salary_min': 58303.38, 'salary_max': 58303.38, 'description': 'About Moment Energy Independent energy is here. Help us deploy it. Energy should be free. Free from aging grids, fragile supply chains, and unnecessa ... (202 characters truncated) ... t a freer future is possible. Moment Energy is the pragmatic liberator of power, the only company certified to turn the largest untapped energy supp…', 'posted_date': '2026-06-03', 'raw_json': '{"salary_min": 58303.38, "redirect_url": "https://www.adzuna.co.uk/jobs/details/5750395286?utm_medium=api&utm_source=a1cca52e", "salary_is_predicted" ... (1067 characters truncated) ... . Moment Energy is the pragmatic liberator of power, the only company certified to turn the largest untapped energy supp\\u2026", "id": "5750395286"}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Senior Back End Software Engineer', 'company': 'Motorola Solutions', 'location': 'Edinburgh, Scotland', 'salary_min': 57307.25, 'salary_max': 57307.25, 'description': 'Company Overview At Motorola Solutions, we believe that everything starts with our people. We’re a global close-knit community, united by the relentl ... (202 characters truncated) ... ies, safer schools, safer hospitals, safer businesses, and ultimately, safer nations. Connect with a career that matters, and help us build a safer …', 'posted_date': '2026-07-10', 'raw_json': '{"salary_is_predicted": "1", "redirect_url": "https://www.adzuna.co.uk/jobs/land/ad/5795616953?se=4GTix0SD8RG64bpm-6Bw6w&utm_medium=api&utm_source=a1 ... (1189 characters truncated) ... S02Qnc2dyIsImkiOiI1Nzk1NjE2OTUzIn0.d-qEGpRINYUc6MPBsL-BqRvvikUAt8k3gCAXPiL-tPE", "title": "Senior Back End Software Engineer", "latitude": 55.943116}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Financial Systems Engineer - Maritime & Shipping Markets', 'company': 'Ec1 Partners', 'location': 'London, UK', 'salary_min': 79572.5, 'salary_max': 79572.5, 'description': 'Job Description Role Overview This role sits at the intersection of financial technology and maritime markets, building systems that support pricing, ... (202 characters truncated) ...  teams in a market-driven environment. Key Responsibilities Build and enhance financial systems supporting maritime trading and brokerage Develop ba…', 'posted_date': '2026-01-20', 'raw_json': '{"title": "Financial Systems Engineer - Maritime & Shipping Markets", "latitude": 51.503378, "contract_time": "full_time", "location": {"area": ["UK" ... (1105 characters truncated) ... sponse::Category", "tag": "it-jobs", "label": "IT Jobs"}, "company": {"display_name": "Ec1 Partners", "__CLASS__": "Adzuna::API::Response::Company"}}'}, {'source': 'adzuna', 'country': 'gb', 'title': 'Software Engineer', 'company': 'Accountancy Action', 'location': 'Hertfordshire, Eastern England', 'salary_min': 70000.0, 'salary_max': 90000.0, 'description': 'Software Engineer Hybrid working 3 days in office Up to 90K Based in Borehamwood, full time r ...
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Inserted 50 rows (gb)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)
# Inserted 50 rows (us)

# %%
with engine.connect() as conn:
    result = conn.execute(text("DELETE FROM job_postings WHERE country IS NULL"))
    conn.commit()
    print(f"Deleted {result.rowcount} rows with missing country")
# Out:
# Deleted 0 rows with missing country

# %% [markdown]
# ## 7. Sanity check
# Confirm what landed in the database.

# %%
df_check = pd.read_sql(
    "SELECT country, COUNT(*) AS total, SUM(salary_min IS NOT NULL) AS with_salary FROM job_postings GROUP BY country;",
    con=engine
)
df_check
# Out:
#   country  total  with_salary
# 0      us   1350       1350.0
